# %% [markdown]
# Deep Learning
# =============
#
# Assignment 4
# ------------
#
# Previously in `2_fullyconnected.ipynb` and `3_regularization.ipynb`, we trained fully connected networks to classify [notMNIST](http://yaroslavvb.blogspot.com/2011/09/notmnist-dataset.html) characters.
#
# The goal of this assignment is make the neural network convolutional.

# %%
# These are all the modules we'll be using later. Make sure you can import them
# before proceeding further.
from __future__ import print_function
import numpy as np
import tensorflow as tf
from six.moves import cPickle as pickle
from six.moves import range

# %%
pickle_file = 'notMNIST.pickle'

with open(pickle_file, 'rb') as f:
    save = pickle.load(f)
    train_dataset = save['train_dataset']
    train_labels = save['train_labels']
    valid_dataset = save['valid_dataset']
    valid_labels = save['valid_labels']
    test_dataset = save['test_dataset']
    test_labels = save['test_labels']
    del save  # hint to help gc free up memory
    print('Training set', train_dataset.shape, train_labels.shape)
    print('Validation set', valid_dataset.shape, valid_labels.shape)
    print('Test set', test_dataset.shape, test_labels.shape)
# Out:
# Training set (200000, 28, 28) (200000,)
# Validation set (10000, 28, 28) (10000,)
# Test set (10000, 28, 28) (10000,)

# %% [markdown]
# Reformat into a TensorFlow-friendly shape:
# - convolutions need the image data formatted as a cube (width by height by #channels)
# - labels as float 1-hot encodings.

# %%
image_size = 28
num_labels = 10
num_channels = 1 # grayscale

import numpy as np

def reformat(dataset, labels):
    dataset = dataset.reshape(
    (-1, image_size, image_size, num_channels)).astype(np.float32)
    labels = (np.arange(num_labels) == labels[:,None]).astype(np.float32)
    return dataset, labels
train_dataset, train_labels = reformat(train_dataset, train_labels)
valid_dataset, valid_labels = reformat(valid_dataset, valid_labels)
test_dataset, test_labels = reformat(test_dataset, test_labels)
print('Training set', train_dataset.shape, train_labels.shape)
print('Validation set', valid_dataset.shape, valid_labels.shape)
print('Test set', test_dataset.shape, test_labels.shape)
# Out:
# Training set (200000, 28, 28, 1) (200000, 10)
# Validation set (10000, 28, 28, 1) (10000, 10)
# Test set (10000, 28, 28, 1) (10000, 10)

# %%
def accuracy(predictions, labels):
    return (100.0 * np.sum(np.argmax(predictions, 1) == np.argmax(labels, 1))
          / predictions.shape[0])

# %% [markdown]
# Let's build a small network with two convolutional layers, followed by one fully connected layer. Convolutional networks are more expensive computationally, so we'll limit its depth and number of fully connected nodes.
#
# See document abount `conv2d` : https://www.tensorflow.org/api_docs/python/tf/nn/conv2d

# %%
batch_size = 16
patch_size = 5
depth = 16
num_hidden = 64

graph = tf.Graph()

with graph.as_default():

    # Input data.
    tf_train_dataset = tf.placeholder(
    tf.float32, shape=(batch_size, image_size, image_size, num_channels))
    tf_train_labels = tf.placeholder(tf.float32, shape=(batch_size, num_labels))
    tf_valid_dataset = tf.constant(valid_dataset)
    tf_test_dataset = tf.constant(test_dataset)

    # Variables.
    layer1_weights = tf.Variable(tf.truncated_normal(
      [patch_size, patch_size, num_channels, depth], stddev=0.1))
    layer1_biases = tf.Variable(tf.zeros([depth]))
    layer2_weights = tf.Variable(tf.truncated_normal(
      [patch_size, patch_size, depth, depth], stddev=0.1))
    layer2_biases = tf.Variable(tf.constant(1.0, shape=[depth]))
    layer3_weights = tf.Variable(tf.truncated_normal(
      [image_size // 4 * image_size // 4 * depth, num_hidden], stddev=0.1))
    layer3_biases = tf.Variable(tf.constant(1.0, shape=[num_hidden]))
    layer4_weights = tf.Variable(tf.truncated_normal(
      [num_hidden, num_labels], stddev=0.1))
    layer4_biases = tf.Variable(tf.constant(1.0, shape=[num_labels]))

    # Model.
    def model(data):
        conv = tf.nn.conv2d(data, layer1_weights, [1, 2, 2, 1], padding='SAME')
        hidden = tf.nn.relu(conv + layer1_biases)
        conv = tf.nn.conv2d(hidden, layer2_weights, [1, 2, 2, 1], padding='SAME')
        hidden = tf.nn.relu(conv + layer2_biases)
        shape = hidden.get_shape().as_list()
        reshape = tf.reshape(hidden, [shape[0], shape[1] * shape[2] * shape[3]])
        hidden = tf.nn.relu(tf.matmul(reshape, layer3_weights) + layer3_biases)
        return tf.matmul(hidden, layer4_weights) + layer4_biases

    # Training computation.
    logits = model(tf_train_dataset)
    loss = tf.reduce_mean(
    tf.nn.softmax_cross_entropy_with_logits(logits, tf_train_labels))

    # Optimizer.
    optimizer = tf.train.GradientDescentOptimizer(0.05).minimize(loss)

    # Predictions for the training, validation, and test data.
    train_prediction = tf.nn.softmax(logits)
    valid_prediction = tf.nn.softmax(model(tf_valid_dataset))
    test_prediction = tf.nn.softmax(model(tf_test_dataset))

# %%
num_steps = 1001

with tf.Session(graph=graph) as session:
    tf.global_variables_initializer().run()
    print('Initialized')
    for step in range(num_steps):
        offset = (step * batch_size) % (train_labels.shape[0] - batch_size)
        batch_data = train_dataset[offset:(offset + batch_size), :, :, :]
        batch_labels = train_labels[offset:(offset + batch_size), :]
        feed_dict = {tf_train_dataset : batch_data, tf_train_labels : batch_labels}
        _, l, predictions = session.run(
          [optimizer, loss, train_prediction], feed_dict=feed_dict)
        if (step % 50 == 0):
            print('Minibatch loss at step %d: %f' % (step, l))
            print('Minibatch accuracy: %.1f%%' % accuracy(predictions, batch_labels))
            print('Validation accuracy: %.1f%%' % accuracy(
            valid_prediction.eval(), valid_labels))
    print('Test accuracy: %.1f%%' % accuracy(test_prediction.eval(), test_labels))
# Out:
# Initialized
# Minibatch loss at step 0: 2.712572
# Minibatch accuracy: 12.5%
# Validation accuracy: 10.0%
# Minibatch loss at step 50: 1.668136
# Minibatch accuracy: 37.5%
# Validation accuracy: 52.0%
# Minibatch loss at step 100: 1.005960
# Minibatch accuracy: 68.8%
# Validation accuracy: 70.7%
# Minibatch loss at step 150: 0.879643
# Minibatch accuracy: 81.2%
# Validation accuracy: 74.1%
# Minibatch loss at step 200: 0.879069
# Minibatch accuracy: 81.2%
# Validation accuracy: 77.2%
# Minibatch loss at step 250: 0.865204
# Minibatch accuracy: 75.0%
# Validation accuracy: 76.5%
# Minibatch loss at step 300: 0.487148
# Minibatch accuracy: 81.2%
# Validation accuracy: 79.2%
# Minibatch loss at step 350: 0.599675
# Minibatch accuracy: 81.2%
# Validation accuracy: 77.8%
# Minibatch loss at step 400: 0.355402
# Minibatch accuracy: 93.8%
# Validation accuracy: 79.5%
# Minibatch loss at step 450: 0.895182
# Minibatch accuracy: 81.2%
# Validation accuracy: 78.8%
# Minibatch loss at step 500: 0.670469
# Minibatch accuracy: 87.5%
# Validation accuracy: 79.7%
# Minibatch loss at step 550: 0.926670
# Minibatch accuracy: 81.2%
# Validation accuracy: 80.6%
# Minibatch loss at step 600: 0.161766
# Minibatch accuracy: 93.8%
# Validation accuracy: 81.3%
# Minibatch loss at step 650: 1.094872
# Minibatch accuracy: 81.2%
# Validation accuracy: 81.4%
# Minibatch loss at step 700: 0.988538
# Minibatch accuracy: 68.8%
# Validation accuracy: 82.0%
# Minibatch loss at step 750: 0.102529
# Minibatch accuracy: 93.8%
# Validation accuracy: 82.2%
# Minibatch loss at step 800: 0.763389
# Minibatch accuracy: 68.8%
# Validation accuracy: 81.6%
# Minibatch loss at step 850: 0.789921
# Minibatch accuracy: 81.2%
# Validation accuracy: 82.3%
# Minibatch loss at step 900: 0.555025
# Minibatch accuracy: 81.2%
# Validation accuracy: 82.8%
# Minibatch loss at step 950: 0.678362
# Minibatch accuracy: 75.0%
# Validation accuracy: 83.0%
# Minibatch loss at step 1000: 0.562271
# Minibatch accuracy: 81.2%
# Validation accuracy: 83.0%
# Test accuracy: 90.0%

# %% [markdown]
# ---
# Problem 1
# ---------
#
# The convolutional model above uses convolutions with stride 2 to reduce the dimensionality. Replace the strides by a max pooling operation (`nn.max_pool()`) of stride 2 and kernel size 2.
#
# ---

# %%
batch_size = 16
patch_size = 5
depth = 16
num_hidden = 64

graph = tf.Graph()

with graph.as_default():

    # Input data.
    tf_train_dataset = tf.placeholder(
    tf.float32, shape=(batch_size, image_size, image_size, num_channels))
    tf_train_labels = tf.placeholder(tf.float32, shape=(batch_size, num_labels))
    tf_valid_dataset = tf.constant(valid_dataset)
    tf_test_dataset = tf.constant(test_dataset)

    # Variables.
    layer1_weights = tf.Variable(tf.truncated_normal(
      [patch_size, patch_size, num_channels, depth], stddev=0.1))
    layer1_biases = tf.Variable(tf.zeros([depth]))
    layer2_weights = tf.Variable(tf.truncated_normal(
      [patch_size, patch_size, depth, depth], stddev=0.1))
    layer2_biases = tf.Variable(tf.constant(1.0, shape=[depth]))
    layer3_weights = tf.Variable(tf.truncated_normal(
      [image_size // 4 * image_size // 4 * depth, num_hidden], stddev=0.1))
    layer3_biases = tf.Variable(tf.constant(1.0, shape=[num_hidden]))
    layer4_weights = tf.Variable(tf.truncated_normal(
      [num_hidden, num_labels], stddev=0.1))
    layer4_biases = tf.Variable(tf.constant(1.0, shape=[num_labels]))

    # Model.
    def model(data):
        conv = tf.nn.conv2d(data, layer1_weights, [1, 1, 1, 1], padding='SAME')
        hidden = tf.nn.relu(conv + layer1_biases)
        hidden = tf.nn.max_pool(hidden, ksize=[1,2,2,1], strides=[1,2,2,1], padding='SAME')
        conv = tf.nn.conv2d(hidden, layer2_weights, [1, 1, 1, 1], padding='SAME')
        hidden = tf.nn.relu(conv + layer2_biases)
        hidden = tf.nn.max_pool(hidden, ksize=[1,2,2,1], strides=[1,2,2,1], padding='SAME')
        shape = hidden.get_shape().as_list()
        reshape = tf.reshape(hidden, [shape[0], shape[1] * shape[2] * shape[3]])
        hidden = tf.nn.relu(tf.matmul(reshape, layer3_weights) + layer3_biases)
        return tf.matmul(hidden, layer4_weights) + layer4_biases

    # Training computation.
    logits = model(tf_train_dataset)
    loss = tf.reduce_mean(
    tf.nn.softmax_cross_entropy_with_logits(logits, tf_train_labels))

    # Optimizer.
    optimizer = tf.train.GradientDescentOptimizer(0.05).minimize(loss)

    # Predictions for the training, validation, and test data.
    train_prediction = tf.nn.softmax(logits)
    valid_prediction = tf.nn.softmax(model(tf_valid_dataset))
    test_prediction = tf.nn.softmax(model(tf_test_dataset))

# %%
num_steps = 1001

with tf.Session(graph=graph) as session:
    tf.global_variables_initializer().run()
    print('Initialized')
    for step in range(num_steps):
        offset = (step * batch_size) % (train_labels.shape[0] - batch_size)
        batch_data = train_dataset[offset:(offset + batch_size), :, :, :]
        batch_labels = train_labels[offset:(offset + batch_size), :]
        feed_dict = {tf_train_dataset : batch_data, tf_train_labels : batch_labels}
        _, l, predictions = session.run(
          [optimizer, loss, train_prediction], feed_dict=feed_dict)
        if (step % 50 == 0):
            print('Minibatch loss at step %d: %f' % (step, l))
            print('Minibatch accuracy: %.1f%%' % accuracy(predictions, batch_labels))
            print('Validation accuracy: %.1f%%' % accuracy(
            valid_prediction.eval(), valid_labels))
    print('Test accuracy: %.1f%%' % accuracy(test_prediction.eval(), test_labels))
# Out:
# Initialized
# Minibatch loss at step 0: 3.938912
# Minibatch accuracy: 6.2%
# Validation accuracy: 10.0%
# Minibatch loss at step 50: 1.575956
# Minibatch accuracy: 37.5%
# Validation accuracy: 49.2%
# Minibatch loss at step 100: 1.405379
# Minibatch accuracy: 37.5%
# Validation accuracy: 59.4%
# Minibatch loss at step 150: 0.976006
# Minibatch accuracy: 81.2%
# Validation accuracy: 73.4%
# Minibatch loss at step 200: 1.105635
# Minibatch accuracy: 62.5%
# Validation accuracy: 76.9%
# Minibatch loss at step 250: 1.111861
# Minibatch accuracy: 68.8%
# Validation accuracy: 77.4%
# Minibatch loss at step 300: 0.514878
# Minibatch accuracy: 81.2%
# Validation accuracy: 78.8%
# Minibatch loss at step 350: 0.621121
# Minibatch accuracy: 87.5%
# Validation accuracy: 78.2%
# Minibatch loss at step 400: 0.182394
# Minibatch accuracy: 100.0%
# Validation accuracy: 78.8%
# Minibatch loss at step 450: 0.657340
# Minibatch accuracy: 81.2%
# Validation accuracy: 79.6%
# Minibatch loss at step 500: 0.787313
# Minibatch accuracy: 81.2%
# Validation accuracy: 80.7%
# Minibatch loss at step 550: 0.641787
# Minibatch accuracy: 81.2%
# Validation accuracy: 81.7%
# Minibatch loss at step 600: 0.196867
# Minibatch accuracy: 93.8%
# Validation accuracy: 80.9%
# Minibatch loss at step 650: 1.016294
# Minibatch accuracy: 87.5%
# Validation accuracy: 81.8%
# Minibatch loss at step 700: 0.933682
# Minibatch accuracy: 81.2%
# Validation accuracy: 82.3%
# Minibatch loss at step 750: 0.049936
# Minibatch accuracy: 100.0%
# Validation accuracy: 82.9%
# Minibatch loss at step 800: 0.668910
# Minibatch accuracy: 75.0%
# Validation accuracy: 82.7%
# Minibatch loss at step 850: 0.741696
# Minibatch accuracy: 81.2%
# Validation accuracy: 83.2%
# Minibatch loss at step 900: 0.676675
# Minibatch accuracy: 81.2%
# Validation accuracy: 84.1%
# Minibatch loss at step 950: 0.502298
# Minibatch accuracy: 81.2%
# Validation accuracy: 83.7%
# Minibatch loss at step 1000: 0.647210
# Minibatch accuracy: 81.2%
# Validation accuracy: 83.9%
# Test accuracy: 89.8%

# %% [markdown]
# ---
# Problem 2
# ---------
#
# Try to get the best performance you can using a convolutional net. Look for example at the classic [LeNet5](http://yann.lecun.com/exdb/lenet/) architecture, adding Dropout, and/or adding learning rate decay.
#
# ---

# %%
batch_size = 16
patch_size = 5
depth = 8
num_hidden = 64

graph = tf.Graph()

with graph.as_default():

    # Input data.
    tf_train_dataset = tf.placeholder(
    tf.float32, shape=(batch_size, image_size, image_size, num_channels))
    tf_train_labels = tf.placeholder(tf.float32, shape=(batch_size, num_labels))
    tf_valid_dataset = tf.constant(valid_dataset)
    tf_test_dataset = tf.constant(test_dataset)

    # Variables.
    layer1_weights = tf.Variable(tf.truncated_normal(
      [patch_size, patch_size, num_channels, depth], stddev=0.1))
    layer1_biases = tf.Variable(tf.zeros([depth]))
    layer2_weights = tf.Variable(tf.truncated_normal(
      [patch_size, patch_size, depth, depth], stddev=0.1))
    layer2_biases = tf.Variable(tf.constant(1.0, shape=[depth]))
    layer3_weights = tf.Variable(tf.truncated_normal(
      [image_size // 4 * image_size // 4 * depth, num_hidden], stddev=0.1))
    layer3_biases = tf.Variable(tf.constant(1.0, shape=[num_hidden]))
    layer4_weights = tf.Variable(tf.truncated_normal(
      [num_hidden, num_labels], stddev=0.1))
    layer4_biases = tf.Variable(tf.constant(1.0, shape=[num_labels]))

    # Model.
    def model(data):
        conv = tf.nn.conv2d(data, layer1_weights, [1, 1, 1, 1], padding='SAME')
        hidden = tf.nn.relu(conv + layer1_biases)
        hidden = tf.nn.max_pool(hidden, ksize=[1,2,2,1], strides=[1,2,2,1], padding='SAME')
        conv = tf.nn.conv2d(hidden, layer2_weights, [1, 1, 1, 1], padding='SAME')
        hidden = tf.nn.relu(conv + layer2_biases)
        hidden = tf.nn.max_pool(hidden, ksize=[1,2,2,1], strides=[1,2,2,1], padding='SAME')
        shape = hidden.get_shape().as_list()
        reshape = tf.reshape(hidden, [shape[0], shape[1] * shape[2] * shape[3]])
        hidden = tf.nn.relu(tf.matmul(reshape, layer3_weights) + layer3_biases)
        return tf.matmul(hidden, layer4_weights) + layer4_biases

    # Training computation.
    logits = model(tf_train_dataset)
    loss = tf.reduce_mean(
    tf.nn.softmax_cross_entropy_with_logits(logits, tf_train_labels))

    # Optimizer.
    optimizer = tf.train.GradientDescentOptimizer(0.01).minimize(loss)

    # Predictions for the training, validation, and test data.
    train_prediction = tf.nn.softmax(logits)
    valid_prediction = tf.nn.softmax(model(tf_valid_dataset))
    test_prediction = tf.nn.softmax(model(tf_test_dataset))

# %%
num_steps = 6001

with tf.Session(graph=graph) as session:
    tf.global_variables_initializer().run()
    print('Initialized')
    for step in range(num_steps):
        offset = (step * batch_size) % (train_labels.shape[0] - batch_size)
        batch_data = train_dataset[offset:(offset + batch_size), :, :, :]
        batch_labels = train_labels[offset:(offset + batch_size), :]
        feed_dict = {tf_train_dataset : batch_data, tf_train_labels : batch_labels}
        _, l, predictions = session.run(
          [optimizer, loss, train_prediction], feed_dict=feed_dict)
        if (step % 50 == 0):
            print('Minibatch loss at step %d: %f' % (step, l))
            print('Minibatch accuracy: %.1f%%' % accuracy(predictions, batch_labels))
            print('Validation accuracy: %.1f%%' % accuracy(
            valid_prediction.eval(), valid_labels))
    print('Test accuracy: %.1f%%' % accuracy(test_prediction.eval(), test_labels))
# Out:
# Initialized
# Minibatch loss at step 0: 3.414664
# Minibatch accuracy: 12.5%
# Validation accuracy: 10.0%
# Minibatch loss at step 50: 2.303552
# Minibatch accuracy: 6.2%
# Validation accuracy: 8.8%
# Minibatch loss at step 100: 2.297456
# Minibatch accuracy: 18.8%
# Validation accuracy: 18.9%
# Minibatch loss at step 150: 2.229763
# Minibatch accuracy: 12.5%
# Validation accuracy: 25.6%
# Minibatch loss at step 200: 1.970271
# Minibatch accuracy: 43.8%
# Validation accuracy: 36.7%
# Minibatch loss at step 250: 1.904512
# Minibatch accuracy: 31.2%
# Validation accuracy: 45.7%
# Minibatch loss at step 300: 0.986932
# Minibatch accuracy: 68.8%
# Validation accuracy: 63.9%
# Minibatch loss at step 350: 1.083600
# Minibatch accuracy: 68.8%
# Validation accuracy: 67.9%
# Minibatch loss at step 400: 0.574085
# Minibatch accuracy: 87.5%
# Validation accuracy: 69.8%
# Minibatch loss at step 450: 0.915179
# Minibatch accuracy: 75.0%
# Validation accuracy: 70.6%
# Minibatch loss at step 500: 1.169651
# Minibatch accuracy: 75.0%
# Validation accuracy: 77.0%
# Minibatch loss at step 550: 1.032527
# Minibatch accuracy: 81.2%
# Validation accuracy: 76.1%
# Minibatch loss at step 600: 0.263048
# Minibatch accuracy: 93.8%
# Validation accuracy: 76.8%
# Minibatch loss at step 650: 1.103977
# Minibatch accuracy: 75.0%
# Validation accuracy: 78.1%
# Minibatch loss at step 700: 0.835527
# Minibatch accuracy: 81.2%
# Validation accuracy: 77.6%
# Minibatch loss at step 750: 0.167051
# Minibatch accuracy: 100.0%
# Validation accuracy: 77.8%
# Minibatch loss at step 800: 0.675350
# Minibatch accuracy: 75.0%
# Validation accuracy: 79.6%
# Minibatch loss at step 850: 0.951966
# Minibatch accuracy: 81.2%
# Validation accuracy: 77.8%
# Minibatch loss at step 900: 0.478578
# Minibatch accuracy: 87.5%
# Validation accuracy: 79.5%
# Minibatch loss at step 950: 0.907884
# Minibatch accuracy: 81.2%
# Validation accuracy: 79.9%
# Minibatch loss at step 1000: 0.785658
# Minibatch accuracy: 81.2%
# Validation accuracy: 79.6%
# Minibatch loss at step 1050: 0.629649
# Minibatch accuracy: 87.5%
# Validation accuracy: 78.0%
# Minibatch loss at step 1100: 0.585419
# Minibatch accuracy: 81.2%
# Validation accuracy: 79.8%
# Minibatch loss at step 1150: 0.478932
# Minibatch accuracy: 81.2%
# Validation accuracy: 81.5%
# Minibatch loss at step 1200: 1.206944
# Minibatch accuracy: 68.8%
# Validation accuracy: 81.3%
# Minibatch loss at step 1250: 0.904971
# Minibatch accuracy: 75.0%
# Validation accuracy: 79.8%
# Minibatch loss at step 1300: 0.369109
# Minibatch accuracy: 87.5%
# Validation accuracy: 80.0%
# Minibatch loss at step 1350: 1.245848
# Minibatch accuracy: 56.2%
# Validation accuracy: 80.8%
# Minibatch loss at step 1400: 0.548120
# Minibatch accuracy: 81.2%
# Validation accuracy: 80.8%
# Minibatch loss at step 1450: 0.376367
# Minibatch accuracy: 93.8%
# Validation accuracy: 81.5%
# Minibatch loss at step 1500: 0.978081
# Minibatch accuracy: 75.0%
# Validation accuracy: 82.5%
# Minibatch loss at step 1550: 0.664788
# Minibatch accuracy: 87.5%
# Validation accuracy: 81.9%
# Minibatch loss at step 1600: 1.176723
# Minibatch accuracy: 68.8%
# Validation accuracy: 81.4%
# Minibatch loss at step 1650: 0.791558
# Minibatch accuracy: 81.2%
# Validation accuracy: 82.5%
# Minibatch loss at step 1700: 0.876507
# Minibatch accuracy: 81.2%
# Validation accuracy: 82.7%
# Minibatch loss at step 1750: 0.588666
# Minibatch accuracy: 81.2%
# Validation accuracy: 82.5%
# Minibatch loss at step 1800: 0.588649
# Minibatch accuracy: 81.2%
# Validation accuracy: 82.7%
# Minibatch loss at step 1850: 0.884484
# Minibatch accuracy: 75.0%
# Validation accuracy: 82.6%
# Minibatch loss at step 1900: 0.746551
# Minibatch accuracy: 75.0%
# Validation accuracy: 83.1%
# Minibatch loss at step 1950: 0.951144
# Minibatch accuracy: 75.0%
# Validation accuracy: 83.1%
# Minibatch loss at step 2000: 0.092774
# Minibatch accuracy: 100.0%
# Validation accuracy: 82.8%
# Minibatch loss at step 2050: 0.809750
# Minibatch accuracy: 75.0%
# Validation accuracy: 83.0%
# Minibatch loss at step 2100: 0.313909
# Minibatch accuracy: 93.8%
# Validation accuracy: 83.2%
# Minibatch loss at step 2150: 0.780329
# Minibatch accuracy: 81.2%
# Validation accuracy: 83.1%
# Minibatch loss at step 2200: 0.518483
# Minibatch accuracy: 87.5%
# Validation accuracy: 83.3%
# Minibatch loss at step 2250: 0.865117
# Minibatch accuracy: 81.2%
# Validation accuracy: 83.8%
# Minibatch loss at step 2300: 0.646411
# Minibatch accuracy: 87.5%
# Validation accuracy: 82.0%
# Minibatch loss at step 2350: 0.622014
# Minibatch accuracy: 81.2%
# Validation accuracy: 83.4%
# Minibatch loss at step 2400: 0.496751
# Minibatch accuracy: 75.0%
# Validation accuracy: 83.0%
# Minibatch loss at step 2450: 0.524528
# Minibatch accuracy: 75.0%
# Validation accuracy: 83.7%
# Minibatch loss at step 2500: 0.690440
# Minibatch accuracy: 81.2%
# Validation accuracy: 83.4%
# Minibatch loss at step 2550: 0.631855
# Minibatch accuracy: 75.0%
# Validation accuracy: 83.8%
# Minibatch loss at step 2600: 0.313561
# Minibatch accuracy: 93.8%
# Validation accuracy: 84.0%
# Minibatch loss at step 2650: 0.368008
# Minibatch accuracy: 93.8%
# Validation accuracy: 84.5%
# Minibatch loss at step 2700: 0.349387
# Minibatch accuracy: 93.8%
# Validation accuracy: 83.8%
# Minibatch loss at step 2750: 1.239229
# Minibatch accuracy: 81.2%
# Validation accuracy: 83.9%
# Minibatch loss at step 2800: 0.622596
# Minibatch accuracy: 81.2%
# Validation accuracy: 84.2%
# Minibatch loss at step 2850: 0.105990
# Minibatch accuracy: 100.0%
# Validation accuracy: 84.4%
# Minibatch loss at step 2900: 0.707386
# Minibatch accuracy: 75.0%
# Validation accuracy: 83.6%
# Minibatch loss at step 2950: 0.481059
# Minibatch accuracy: 87.5%
# Validation accuracy: 84.1%
# Minibatch loss at step 3000: 0.737326
# Minibatch accuracy: 81.2%
# Validation accuracy: 84.3%
# Minibatch loss at step 3050: 0.429999
# Minibatch accuracy: 93.8%
# Validation accuracy: 84.3%
# Minibatch loss at step 3100: 0.684443
# Minibatch accuracy: 81.2%
# Validation accuracy: 84.1%
# Minibatch loss at step 3150: 0.609094
# Minibatch accuracy: 81.2%
# Validation accuracy: 84.3%
# Minibatch loss at step 3200: 0.530952
# Minibatch accuracy: 87.5%
# Validation accuracy: 84.1%
# Minibatch loss at step 3250: 0.341463
# Minibatch accuracy: 87.5%
# Validation accuracy: 84.2%
# Minibatch loss at step 3300: 0.213883
# Minibatch accuracy: 93.8%
# Validation accuracy: 84.9%
# Minibatch loss at step 3350: 0.350500
# Minibatch accuracy: 87.5%
# Validation accuracy: 85.0%
# Minibatch loss at step 3400: 0.506309
# Minibatch accuracy: 87.5%
# Validation accuracy: 84.5%
# Minibatch loss at step 3450: 0.493303
# Minibatch accuracy: 81.2%
# Validation accuracy: 84.9%
# Minibatch loss at step 3500: 0.569321
# Minibatch accuracy: 81.2%
# Validation accuracy: 83.7%
# Minibatch loss at step 3550: 0.415039
# Minibatch accuracy: 87.5%
# Validation accuracy: 84.9%
# Minibatch loss at step 3600: 0.137931
# Minibatch accuracy: 93.8%
# Validation accuracy: 84.8%
# Minibatch loss at step 3650: 0.862815
# Minibatch accuracy: 81.2%
# Validation accuracy: 84.8%
# Minibatch loss at step 3700: 1.564778
# Minibatch accuracy: 56.2%
# Validation accuracy: 84.5%
# Minibatch loss at step 3750: 0.783953
# Minibatch accuracy: 75.0%
# Validation accuracy: 85.2%
# Minibatch loss at step 3800: 0.170110
# Minibatch accuracy: 93.8%
# Validation accuracy: 85.5%
# Minibatch loss at step 3850: 0.360159
# Minibatch accuracy: 93.8%
# Validation accuracy: 85.3%
# Minibatch loss at step 3900: 0.222114
# Minibatch accuracy: 100.0%
# Validation accuracy: 85.2%
# Minibatch loss at step 3950: 0.029349
# Minibatch accuracy: 100.0%
# Validation accuracy: 85.2%
# Minibatch loss at step 4000: 0.543589
# Minibatch accuracy: 81.2%
# Validation accuracy: 85.2%
# Minibatch loss at step 4050: 0.696479
# Minibatch accuracy: 68.8%
# Validation accuracy: 83.0%
# Minibatch loss at step 4100: 0.599253
# Minibatch accuracy: 81.2%
# Validation accuracy: 85.4%
# Minibatch loss at step 4150: 1.177594
# Minibatch accuracy: 75.0%
# Validation accuracy: 85.2%
# Minibatch loss at step 4200: 1.197672
# Minibatch accuracy: 75.0%
# Validation accuracy: 85.1%
# Minibatch loss at step 4250: 0.334507
# Minibatch accuracy: 87.5%
# Validation accuracy: 84.6%
# Minibatch loss at step 4300: 0.476237
# Minibatch accuracy: 87.5%
# Validation accuracy: 84.8%
# Minibatch loss at step 4350: 0.314744
# Minibatch accuracy: 87.5%
# Validation accuracy: 85.1%
# Minibatch loss at step 4400: 1.051449
# Minibatch accuracy: 68.8%
# Validation accuracy: 85.6%
# Minibatch loss at step 4450: 0.729270
# Minibatch accuracy: 81.2%
# Validation accuracy: 85.2%
# Minibatch loss at step 4500: 0.630152
# Minibatch accuracy: 87.5%
# Validation accuracy: 85.6%
# Minibatch loss at step 4550: 0.367323
# Minibatch accuracy: 87.5%
# Validation accuracy: 85.4%
# Minibatch loss at step 4600: 0.532031
# Minibatch accuracy: 87.5%
# Validation accuracy: 85.2%
# Minibatch loss at step 4650: 0.792290
# Minibatch accuracy: 81.2%
# Validation accuracy: 85.0%
# Minibatch loss at step 4700: 0.493661
# Minibatch accuracy: 87.5%
# Validation accuracy: 85.5%
# Minibatch loss at step 4750: 0.990886
# Minibatch accuracy: 62.5%
# Validation accuracy: 85.3%
# Minibatch loss at step 4800: 0.175679
# Minibatch accuracy: 100.0%
# Validation accuracy: 85.4%
# Minibatch loss at step 4850: 0.369622
# Minibatch accuracy: 87.5%
# Validation accuracy: 85.5%
# Minibatch loss at step 4900: 0.045672
# Minibatch accuracy: 100.0%
# Validation accuracy: 85.5%
# Minibatch loss at step 4950: 0.153024
# Minibatch accuracy: 93.8%
# Validation accuracy: 85.7%
# Minibatch loss at step 5000: 0.826201
# Minibatch accuracy: 68.8%
# Validation accuracy: 85.3%
# Minibatch loss at step 5050: 0.273258
# Minibatch accuracy: 93.8%
# Validation accuracy: 85.6%
# Minibatch loss at step 5100: 0.458516
# Minibatch accuracy: 93.8%
# Validation accuracy: 85.8%
# Minibatch loss at step 5150: 0.726971
# Minibatch accuracy: 75.0%
# Validation accuracy: 85.1%
# Minibatch loss at step 5200: 0.198057
# Minibatch accuracy: 93.8%
# Validation accuracy: 85.5%
# Minibatch loss at step 5250: 0.195859
# Minibatch accuracy: 93.8%
# Validation accuracy: 85.6%
# Minibatch loss at step 5300: 0.327958
# Minibatch accuracy: 93.8%
# Validation accuracy: 85.6%
# Minibatch loss at step 5350: 0.268832
# Minibatch accuracy: 93.8%
# Validation accuracy: 85.2%
# Minibatch loss at step 5400: 0.460440
# Minibatch accuracy: 87.5%
# Validation accuracy: 85.9%
# Minibatch loss at step 5450: 0.536159
# Minibatch accuracy: 93.8%
# Validation accuracy: 85.6%
# Minibatch loss at step 5500: 0.801117
# Minibatch accuracy: 75.0%
# Validation accuracy: 85.2%
# Minibatch loss at step 5550: 0.519850
# Minibatch accuracy: 81.2%
# Validation accuracy: 86.1%
# Minibatch loss at step 5600: 0.406398
# Minibatch accuracy: 81.2%
# Validation accuracy: 85.8%
# Minibatch loss at step 5650: 0.443408
# Minibatch accuracy: 81.2%
# Validation accuracy: 85.8%
# Minibatch loss at step 5700: 0.455441
# Minibatch accuracy: 87.5%
# Validation accuracy: 86.2%
# Minibatch loss at step 5750: 0.628901
# Minibatch accuracy: 75.0%
# Validation accuracy: 86.2%
# Minibatch loss at step 5800: 0.263446
# Minibatch accuracy: 93.8%
# Validation accuracy: 85.5%
# Minibatch loss at step 5850: 0.894695
# Minibatch accuracy: 81.2%
# Validation accuracy: 86.1%
# Minibatch loss at step 5900: 0.846356
# Minibatch accuracy: 75.0%
# Validation accuracy: 86.0%
# Minibatch loss at step 5950: 0.583720
# Minibatch accuracy: 81.2%
# Validation accuracy: 86.2%
# Minibatch loss at step 6000: 0.181540
# Minibatch accuracy: 100.0%
# Validation accuracy: 85.8%
# Test accuracy: 92.0%
