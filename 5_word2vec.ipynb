# %% [markdown]
# Deep Learning
# =============
#
# Assignment 5
# ------------
#
# The goal of this assignment is to train a Word2Vec skip-gram model over [Text8](http://mattmahoney.net/dc/textdata) data.

# %%
# These are all the modules we'll be using later. Make sure you can import them
# before proceeding further.
# %matplotlib inline
from __future__ import print_function
import collections
import math
import numpy as np
import os
import random
import tensorflow as tf
import zipfile
from matplotlib import pylab
from six.moves import range
from six.moves.urllib.request import urlretrieve
from sklearn.manifold import TSNE

# %% [markdown]
# Download the data from the source website if necessary.

# %%
url = 'http://mattmahoney.net/dc/'

def maybe_download(filename, expected_bytes):
    """Download a file if not present, and make sure it's the right size."""
    if not os.path.exists(filename):
        filename, _ = urlretrieve(url + filename, filename)
    statinfo = os.stat(filename)
    if statinfo.st_size == expected_bytes:
        print('Found and verified %s' % filename)
    else:
        print(statinfo.st_size)
        raise Exception(
          'Failed to verify ' + filename + '. Can you get to it with a browser?')
    return filename

filename = maybe_download('text8.zip', 31344016)
# Out:
# Found and verified text8.zip

# %% [markdown]
# Read the data into a string.

# %%
def read_data(filename):
    """Extract the first file enclosed in a zip file as a list of words"""
    with zipfile.ZipFile(filename) as f:
        data = tf.compat.as_str(f.read(f.namelist()[0])).split()
    return data
  
words = read_data(filename)
print('Data size %d' % len(words))
# Out:
# Data size 17005207

# %% [markdown]
# Build the dictionary and replace rare words with UNK token.

# %%
vocabulary_size = 50000

def build_dataset(words):
    count = [['UNK', -1]]
    count.extend(collections.Counter(words).most_common(vocabulary_size - 1))
    dictionary = dict()
    for word, _ in count:
        dictionary[word] = len(dictionary)
    data = list()
    unk_count = 0
    for word in words:
        if word in dictionary:
            index = dictionary[word]
        else:
            index = 0  # dictionary['UNK']
            unk_count = unk_count + 1
        data.append(index)
    count[0][1] = unk_count
    reverse_dictionary = dict(zip(dictionary.values(), dictionary.keys())) 
    return data, count, dictionary, reverse_dictionary

data, count, dictionary, reverse_dictionary = build_dataset(words)
print('Most common words (+UNK)', count[:5])
print('Sample data', data[:10])
del words  # Hint to reduce memory.
# Out:
# Most common words (+UNK) [['UNK', 418391], ('the', 1061396), ('of', 593677), ('and', 416629), ('one', 411764)]
# Sample data [5242, 3082, 12, 6, 195, 2, 3136, 46, 59, 156]

# %% [markdown]
# Function to generate a training batch for the skip-gram model.

# %%
data_index = 0

def generate_batch(batch_size, num_skips, skip_window):
    global data_index
    assert batch_size % num_skips == 0
    assert num_skips <= 2 * skip_window
    batch = np.ndarray(shape=(batch_size), dtype=np.int32)
    labels = np.ndarray(shape=(batch_size, 1), dtype=np.int32)
    span = 2 * skip_window + 1 # [ skip_window target skip_window ]
    buffer = collections.deque(maxlen=span)
    for _ in range(span):
        buffer.append(data[data_index])
        data_index = (data_index + 1) % len(data)
    for i in range(batch_size // num_skips):
        target = skip_window  # target label at the center of the buffer
        targets_to_avoid = [ skip_window ]
        for j in range(num_skips):
            while target in targets_to_avoid:
                target = random.randint(0, span - 1)
            targets_to_avoid.append(target)
            batch[i * num_skips + j] = buffer[skip_window]
            labels[i * num_skips + j, 0] = buffer[target]
        buffer.append(data[data_index])
        data_index = (data_index + 1) % len(data)
    return batch, labels

print('data:', [reverse_dictionary[di] for di in data[:8]])

for num_skips, skip_window in [(2, 1), (4, 2)]:
    data_index = 0
    batch, labels = generate_batch(batch_size=8, num_skips=num_skips, skip_window=skip_window)
    print('\nwith num_skips = %d and skip_window = %d:' % (num_skips, skip_window))
    print('    batch:', [reverse_dictionary[bi] for bi in batch])
    print('    labels:', [reverse_dictionary[li] for li in labels.reshape(8)])
# Out:
# data: ['anarchism', 'originated', 'as', 'a', 'term', 'of', 'abuse', 'first']
#
# with num_skips = 2 and skip_window = 1:
#     batch: ['originated', 'originated', 'as', 'as', 'a', 'a', 'term', 'term']
#     labels: ['anarchism', 'as', 'originated', 'a', 'term', 'as', 'of', 'a']
#
# with num_skips = 4 and skip_window = 2:
#     batch: ['as', 'as', 'as', 'as', 'a', 'a', 'a', 'a']
#     labels: ['term', 'a', 'originated', 'anarchism', 'term', 'of', 'as', 'originated']

# %% [markdown]
# Train a skip-gram model.

# %%
batch_size = 128
embedding_size = 128 # Dimension of the embedding vector.
skip_window = 1 # How many words to consider left and right.
num_skips = 2 # How many times to reuse an input to generate a label.
# We pick a random validation set to sample nearest neighbors. here we limit the
# validation samples to the words that have a low numeric ID, which by
# construction are also the most frequent. 
valid_size = 16 # Random set of words to evaluate similarity on.
valid_window = 100 # Only pick dev samples in the head of the distribution.
valid_examples = np.array(random.sample(range(valid_window), valid_size))
num_sampled = 64 # Number of negative examples to sample.

graph = tf.Graph()

with graph.as_default(), tf.device('/cpu:0'):

    # Input data.
    train_dataset = tf.placeholder(tf.int32, shape=[batch_size])
    train_labels = tf.placeholder(tf.int32, shape=[batch_size, 1])
    valid_dataset = tf.constant(valid_examples, dtype=tf.int32)
    
    # Variables.
    embeddings = tf.Variable(
        tf.random_uniform([vocabulary_size, embedding_size], -1.0, 1.0))
    softmax_weights = tf.Variable(
        tf.truncated_normal([vocabulary_size, embedding_size],
                                                 stddev=1.0 / math.sqrt(embedding_size)))
    softmax_biases = tf.Variable(tf.zeros([vocabulary_size]))
    
    # Model.
    # Look up embeddings for inputs.
    # https://www.tensorflow.org/api_docs/python/tf/nn/embedding_lookup
    embed = tf.nn.embedding_lookup(embeddings, train_dataset)
    # Compute the softmax loss, using a sample of the negative labels each time.
    # https://www.tensorflow.org/api_docs/python/tf/nn/sampled_softmax_loss
    loss = tf.reduce_mean(
        tf.nn.sampled_softmax_loss(softmax_weights, softmax_biases, embed,
                                                             train_labels, num_sampled, vocabulary_size))

    # Optimizer.
    optimizer = tf.train.AdagradOptimizer(1.0).minimize(loss)
    
    # Compute the similarity between minibatch examples and all embeddings.
    # We use the cosine distance:
    norm = tf.sqrt(tf.reduce_sum(tf.square(embeddings), 1, keep_dims=True))
    normalized_embeddings = embeddings / norm
    valid_embeddings = tf.nn.embedding_lookup(
        normalized_embeddings, valid_dataset)
    similarity = tf.matmul(valid_embeddings, tf.transpose(normalized_embeddings))

# %%
num_steps = 100001

with tf.Session(graph=graph) as session:
    tf.global_variables_initializer().run()
    print('Initialized')
    average_loss = 0
    for step in range(num_steps):
        batch_data, batch_labels = generate_batch(
            batch_size, num_skips, skip_window)
        feed_dict = {train_dataset : batch_data, train_labels : batch_labels}
        _, l = session.run([optimizer, loss], feed_dict=feed_dict)
        average_loss += l
        if step % 2000 == 0:
            if step > 0:
                average_loss = average_loss / 2000
            # The average loss is an estimate of the loss over the last 2000 batches.
            print('Average loss at step %d: %f' % (step, average_loss))
            average_loss = 0
        # note that this is expensive (~20% slowdown if computed every 500 steps)
        if step % 10000 == 0:
            sim = similarity.eval()
            for i in range(valid_size):
                valid_word = reverse_dictionary[valid_examples[i]]
                top_k = 8 # number of nearest neighbors
                nearest = (-sim[i, :]).argsort()[1:top_k+1]
                log = 'Nearest to %s:' % valid_word
                for k in range(top_k):
                    close_word = reverse_dictionary[nearest[k]]
                    log = '%s %s,' % (log, close_word)
                print(log)
    final_embeddings = normalized_embeddings.eval()
# Out:
# Initialized
# Average loss at step 0: 7.613862
# Nearest to some: lighting, procedural, notepad, clipped, dionysius, guard, amish, derisively,
# Nearest to while: enhances, argon, correspondences, upstairs, dryope, methodology, adamson, carbonaceous,
# Nearest to at: fidel, jammu, bentheim, acetic, quadrature, swamped, linkage, diesels,
# Nearest to d: mcintyre, serine, stansted, abingdon, vaporized, johann, doorstep, pungent,
# Nearest to was: slovaks, clo, erbium, rdenas, pacified, procedure, catalogue, uefa,
# Nearest to between: abhidhamma, argyll, says, focused, cheque, aldermen, pharisees, chihuly,
# Nearest to united: bureaucrat, alters, bnf, persons, fancy, dp, unmop, cannonball,
# Nearest to he: phobos, milo, qassam, reactance, dragon, contrapuntal, pohnpei, pier,
# Nearest to with: disproved, degenerative, hebrews, follow, my, developed, yoruba, exempted,
# Nearest to first: enshrined, poked, liquidity, bmc, populist, thera, cheered, snacks,
# Nearest to states: opcw, urine, watertown, homeless, britten, shouldn, saad, distorted,
# Nearest to which: umi, crafty, preachers, pharmacy, anarchistic, bra, rajasthan, thundering,
# Nearest to however: alberta, zh, tenochtitlan, overhauled, metalworking, beaverbrook, breviary, cowes,
# Nearest to when: hallucinations, normand, marching, ckel, conceit, korah, harsher, positions,
# Nearest to other: lieberman, medici, aggravating, sirhan, sabina, socialism, misty, clearance,
# Nearest to an: furnished, irt, virginian, figueres, discernable, aquifer, number, debilitating,
# Average loss at step 2000: 4.362665
# Average loss at step 4000: 3.862838
# Average loss at step 6000: 3.787600
# Average loss at step 8000: 3.690283
# Average loss at step 10000: 3.613488
# Nearest to some: many, these, dionysius, latham, ammanati, textbooks, changes, most,
# Nearest to while: enhances, tirthankaras, offsets, siddeley, vis, pretended, dryope, hailed,
# Nearest to at: in, graphically, settles, on, rebelled, allan, hacked, glycosides,
# Nearest to d: b, noticeable, frontline, protista, pungent, hudsucker, vaporized, and,
# Nearest to was: is, had, has, were, clo, be, became, by,
# Nearest to between: abhidhamma, cheque, flowery, pharisees, falkirk, chimpanzees, with, tuscany,
# Nearest to united: bureaucrat, alters, infimum, bnf, snails, combats, enclosures, mildred,
# Nearest to he: it, she, they, who, hutcheson, there, reactance, passengers,
# Nearest to with: in, by, from, disproved, for, counselor, sophisticated, into,
# Nearest to first: poked, thera, subregions, pivot, enshrined, archaeologist, windy, liquidity,
# Nearest to states: homeless, opcw, tin, flute, watertown, vanish, falklands, infringed,
# Nearest to which: also, it, bra, this, ascribes, direct, that, who,
# Nearest to however: conjoined, alberta, confederations, yielded, diverged, overhauled, zh, euphonium,
# Nearest to when: gabriel, dodgson, modifying, hallucinations, attentions, anticipation, reelected, if,
# Nearest to other: these, clearance, risk, frederik, different, specific, appended, chojn,
# Nearest to an: navier, virginian, geodesy, the, figueres, debilitating, prerequisite, consistently,
# Average loss at step 12000: 3.603281
# Average loss at step 14000: 3.570997
# Average loss at step 16000: 3.410234
# Average loss at step 18000: 3.457766
# Average loss at step 20000: 3.543872
# Nearest to some: many, these, most, several, all, latham, interludes, topping,
# Nearest to while: enhances, and, tirthankaras, throughout, when, however, pretended, bandage,
# Nearest to at: in, on, during, from, under, graphically, following, allan,
# Nearest to d: b, misgivings, sore, pulls, determinate, nm, johann, independents,
# Nearest to was: is, were, has, had, became, be, been, unfortunately,
# Nearest to between: with, abhidhamma, commanding, from, before, chimpanzees, pharisees, proxima,
# Nearest to united: bureaucrat, enclosures, alters, snails, bnf, leyte, sideline, looming,
# Nearest to he: it, they, she, who, there, which, this, leaps,
# Nearest to with: between, in, by, sophisticated, burghley, into, for, disproved,
# Nearest to first: last, poked, voluntary, subregions, milah, mari, targeted, adria,
# Nearest to states: tin, flute, homeless, mistaking, belong, betrothed, art, infringed,
# Nearest to which: this, who, also, that, it, there, and, he,
# Nearest to however: but, where, and, conjoined, though, confederations, that, anxiolytics,
# Nearest to when: if, where, attentions, gabriel, since, while, diverting, sindhu,
# Nearest to other: many, these, different, specific, various, frederik, such, are,
# Nearest to an: the, figueres, navier, virginian, literate, another, repainted, triple,
# Average loss at step 22000: 3.501751
# Average loss at step 24000: 3.492250
# Average loss at step 26000: 3.479288
# Average loss at step 28000: 3.475514
# Average loss at step 30000: 3.501697
# Nearest to some: many, these, several, most, all, interludes, topping, various,
# Nearest to while: when, however, enhances, were, but, is, are, before,
# Nearest to at: during, in, near, around, on, rebelled, allan, under,
# Nearest to d: b, sore, l, determinate, independents, isin, rejecting, johann,
# Nearest to was: is, had, were, became, has, been, be, by,
# Nearest to between: with, abhidhamma, commanding, pharaohs, before, angry, proxima, behind,
# Nearest to united: leyte, alters, enclosures, bureaucrat, southern, snails, looming, chloroform,
# Nearest to he: she, it, they, who, there, but, eventually, i,
# Nearest to with: between, for, into, by, sophisticated, in, from, during,
# Nearest to first: second, last, erythromycin, same, subregions, windy, mari, creator,
# Nearest to states: tin, flute, mistaking, untrustworthy, belong, homeless, judge, creek,
# Nearest to which: this, that, these, who, what, it, foonly, there,
# Nearest to however: but, when, though, where, while, that, if, clocked,
# Nearest to when: if, where, while, after, though, however, during, before,
# Nearest to other: different, these, specific, various, many, galatians, alcindor, some,
# Nearest to an: figueres, virginian, the, laborers, uncomfortable, another, supermarket, this,
# Average loss at step 32000: 3.501429
# Average loss at step 34000: 3.495124
# Average loss at step 36000: 3.452132
# Average loss at step 38000: 3.299641
# Average loss at step 40000: 3.427982
# Nearest to some: many, these, several, most, this, any, both, various,
# Nearest to while: when, enhances, before, but, however, rodolfo, although, though,
# Nearest to at: during, on, hacked, settles, rebelled, gable, allan, near,
# Nearest to d: b, UNK, johann, w, jenkins, pulls, avril, carne,
# Nearest to was: is, became, were, had, has, been, zip, be,
# Nearest to between: with, behind, within, chimpanzees, among, pharaohs, over, commanding,
# Nearest to united: leyte, southern, enclosures, snails, alters, looming, liffey, bureaucrat,
# Nearest to he: she, it, they, there, who, but, however, i,
# Nearest to with: between, by, burghley, after, pinball, ishaq, toys, for,
# Nearest to first: second, last, final, annihilate, govern, mari, erythromycin, countercult,
# Nearest to states: tin, kingdom, flute, nations, mistaking, homeless, creek, canada,
# Nearest to which: that, this, also, who, it, often, there, but,
# Nearest to however: but, though, that, where, while, if, when, although,
# Nearest to when: if, where, while, before, after, though, until, but,
# Nearest to other: different, galatians, various, some, alcindor, softer, risk, more,
# Nearest to an: virginian, prerequisite, geodesy, laborers, rationalization, uncomfortable, this, glycolytic,
# Average loss at step 42000: 3.432625
# Average loss at step 44000: 3.452817
# Average loss at step 46000: 3.445848
# Average loss at step 48000: 3.356622
# Average loss at step 50000: 3.384779
# Nearest to some: many, these, several, most, both, various, other, those,
# Nearest to while: when, however, although, but, though, before, where, after,
# Nearest to at: during, in, on, against, under, towards, from, near,
# Nearest to d: b, m, johann, f, pulls, signage, pungent, protista,
# Nearest to was: is, became, were, has, had, be, been, seems,
# Nearest to between: with, behind, within, among, in, pharaohs, over, from,
# Nearest to united: leyte, enclosures, alters, snails, southern, looming, sideline, thermochemistry,
# Nearest to he: she, it, they, who, there, eventually, then, this,
# Nearest to with: between, by, trilled, vertebrae, apprentices, when, token, toys,
# Nearest to first: last, second, final, entire, only, next, bilirubin, same,
# Nearest to states: kingdom, tin, nations, flute, canada, mistaking, homeless, marches,
# Nearest to which: this, that, who, also, often, usually, these, there,
# Nearest to however: but, though, although, that, where, while, when, if,
# Nearest to when: if, after, while, where, though, before, however, during,
# Nearest to other: various, different, many, some, softer, specific, alcindor, galatians,
# Nearest to an: coll, the, laborers, legacies, halogens, kidnappings, geodesy, figueres,
# Average loss at step 52000: 3.433886
# Average loss at step 54000: 3.428049
# Average loss at step 56000: 3.435065
# Average loss at step 58000: 3.394624
# Average loss at step 60000: 3.392928
# Nearest to some: many, several, these, most, both, all, this, various,
# Nearest to while: although, before, when, though, after, if, despite, including,
# Nearest to at: during, in, around, under, hairy, near, towards, reached,
# Nearest to d: b, johann, m, l, robbed, carne, r, f,
# Nearest to was: is, became, had, were, has, being, been, be,
# Nearest to between: with, among, in, within, over, pharaohs, behind, unsurprisingly,
# Nearest to united: leyte, enclosures, alters, sideline, snails, southern, looming, thermochemistry,
# Nearest to he: she, it, they, there, who, eventually, then, initiate,
# Nearest to with: between, by, in, burghley, pancras, including, into, coogan,
# Nearest to first: last, second, final, next, only, same, subregions, originally,
# Nearest to states: nations, kingdom, countries, tin, canada, mistaking, state, provinces,
# Nearest to which: that, this, what, who, these, usually, however, also,
# Nearest to however: but, though, although, that, where, when, which, if,
# Nearest to when: if, before, though, after, while, where, although, during,
# Nearest to other: different, various, many, specific, some, alcindor, more, those,
# Nearest to an: laborers, virginian, repainted, coll, figueres, excessive, griffon, luminance,
# Average loss at step 62000: 3.239713
# Average loss at step 64000: 3.253876
# Average loss at step 66000: 3.408380
# Average loss at step 68000: 3.392017
# Average loss at step 70000: 3.357246
# Nearest to some: many, several, these, all, both, most, those, various,
# Nearest to while: although, though, before, when, including, however, if, despite,
# Nearest to at: during, near, allan, on, towards, in, hacked, graphically,
# Nearest to d: b, johann, l, h, pulls, r, carne, w,
# Nearest to was: is, were, has, had, became, been, be, genealogies,
# Nearest to between: with, among, within, pharaohs, in, over, spiral, behind,
# Nearest to united: leyte, alters, inevitably, census, footlights, sideline, bureaucrat, enclosures,
# Nearest to he: she, it, they, there, who, we, eventually, later,
# Nearest to with: between, by, burghley, degenerative, token, when, saturated, including,
# Nearest to first: last, second, final, next, same, infoplease, best, original,
# Nearest to states: nations, kingdom, countries, state, mistaking, tin, marches, injures,
# Nearest to which: that, this, also, these, usually, often, what, but,
# Nearest to however: but, though, although, where, that, while, if, when,
# Nearest to when: if, before, while, after, where, though, however, because,
# Nearest to other: various, different, many, some, specific, alcindor, jingles, others,
# Nearest to an: the, laborers, kidnappings, virginian, rationalization, glycolytic, figueres, repainted,
# Average loss at step 72000: 3.375825
# Average loss at step 74000: 3.342826
# Average loss at step 76000: 3.325759
# Average loss at step 78000: 3.349318
# Average loss at step 80000: 3.378513
# Nearest to some: many, several, most, these, both, various, all, numerous,
# Nearest to while: although, though, before, when, including, despite, or, but,
# Nearest to at: during, in, hacked, towards, on, around, duron, palau,
# Nearest to d: b, g, f, h, l, r, pungent, j,
# Nearest to was: is, became, were, has, had, voss, been, zip,
# Nearest to between: among, with, within, in, pharaohs, over, spiral, against,
# Nearest to united: leyte, alters, census, neighbouring, inevitably, sideline, enclosures, intimacy,
# Nearest to he: she, they, it, there, who, eventually, later, we,
# Nearest to with: between, token, in, when, by, burghley, counselor, using,
# Nearest to first: last, second, next, final, third, same, only, corrected,
# Nearest to states: nations, kingdom, countries, mistaking, state, marches, tin, ahaziah,
# Nearest to which: that, this, usually, also, often, based, what, retinal,
# Nearest to however: but, although, though, that, where, especially, when, diaz,
# Nearest to when: before, if, after, though, during, where, while, since,
# Nearest to other: various, different, many, alcindor, including, others, softer, some,
# Nearest to an: prerequisite, coll, lashes, geodesy, virginian, glycolytic, rationalization, excessive,
# Average loss at step 82000: 3.404872
# Average loss at step 84000: 3.411648
# Average loss at step 86000: 3.387190
# Average loss at step 88000: 3.353722
# Average loss at step 90000: 3.363407
# Nearest to some: many, several, these, most, any, both, numerous, certain,
# Nearest to while: although, before, when, though, despite, where, after, were,
# Nearest to at: during, near, under, on, towards, across, in, before,
# Nearest to d: b, pungent, signage, johann, nm, r, determinate, carne,
# Nearest to was: is, became, had, were, has, be, voss, been,
# Nearest to between: within, among, with, pharaohs, over, against, in, during,
# Nearest to united: leyte, neighbouring, inevitably, alters, census, cowardice, enclosures, sideline,
# Nearest to he: she, it, they, there, who, eventually, this, later,
# Nearest to with: between, in, burghley, using, by, shutout, coogan, muscat,
# Nearest to first: second, last, final, original, same, next, third, infoplease,
# Nearest to states: nations, kingdom, countries, mistaking, provinces, state, canada, union,
# Nearest to which: that, this, also, usually, often, typically, what, but,
# Nearest to however: but, although, though, that, where, especially, there, cases,
# Nearest to when: if, before, while, where, though, after, during, since,
# Nearest to other: various, including, different, alcindor, stances, conservative, specific, scatter,
# Nearest to an: prerequisite, kidnappings, virginian, griffon, glycolytic, rationalization, yap, endless,
# Average loss at step 92000: 3.398619
# Average loss at step 94000: 3.250826
# Average loss at step 96000: 3.361007
# Average loss at step 98000: 3.239585
# Average loss at step 100000: 3.353585
# Nearest to some: many, several, any, these, numerous, certain, all, both,
# Nearest to while: when, although, before, though, and, where, if, are,
# Nearest to at: near, across, towards, through, from, on, during, hairy,
# Nearest to d: b, r, signage, q, johann, lomography, rejecting, w,
# Nearest to was: is, became, been, has, were, had, be, being,
# Nearest to between: among, pharaohs, with, within, spiral, over, in, proxima,
# Nearest to united: leyte, census, neighbouring, alters, enclosures, inevitably, senate, cowardice,
# Nearest to he: she, it, they, there, who, we, this, eventually,
# Nearest to with: between, infix, including, burghley, apse, trilled, shutout, khomeini,
# Nearest to first: last, second, next, final, third, same, original, fifth,
# Nearest to states: nations, kingdom, countries, mistaking, provinces, state, marches, tin,
# Nearest to which: that, this, usually, what, typically, also, who, but,
# Nearest to however: but, although, that, though, especially, where, imprint, while,
# Nearest to when: if, before, while, where, after, though, although, because,
# Nearest to other: various, scatter, specific, others, including, softer, frederik, marston,
# Nearest to an: rationalization, excessive, luminance, virginian, another, coll, ishmael, repainted,

# %%
num_points = 400

tsne = TSNE(perplexity=30, n_components=2, init='pca', n_iter=5000)
two_d_embeddings = tsne.fit_transform(final_embeddings[1:num_points+1, :])

# %%
def plot(embeddings, labels):
    assert embeddings.shape[0] >= len(labels), 'More labels than embeddings'
    pylab.figure(figsize=(15,15))  # in inches
    for i, label in enumerate(labels):
        x, y = embeddings[i,:]
        pylab.scatter(x, y)
        pylab.annotate(label, xy=(x, y), xytext=(5, 2), textcoords='offset points',
                                     ha='right', va='bottom')
    pylab.show()

words = [reverse_dictionary[i] for i in range(1, num_points+1)]
plot(two_d_embeddings, words)

# %% [markdown]
# ---
#
# Problem
# -------
#
# An alternative to skip-gram is another Word2Vec model called [CBOW](http://arxiv.org/abs/1301.3781) (Continuous Bag of Words). In the CBOW model, instead of predicting a context word from a word vector, you predict a word from the sum of all the word vectors in its context. Implement and evaluate a CBOW model trained on the text8 dataset.
#
# ---

# %%
data_index = 0

def generate_batch(batch_size, bag_window):
  global data_index
  span = 2 * bag_window + 1 # [ bag_window target bag_window ]
  batch = np.ndarray(shape=(batch_size, span - 1), dtype=np.int32)
  labels = np.ndarray(shape=(batch_size, 1), dtype=np.int32)  
  buffer = collections.deque(maxlen=span)
  for _ in range(span):
    buffer.append(data[data_index])
    data_index = (data_index + 1) % len(data)
  for i in range(batch_size):
    # just for testing
    buffer_list = list(buffer)
    labels[i, 0] = buffer_list.pop(bag_window)
    batch[i] = buffer_list
    # iterate to the next buffer
    buffer.append(data[data_index])
    data_index = (data_index + 1) % len(data)
  return batch, labels

print('data:', [reverse_dictionary[di] for di in data[:16]])

for bag_window in [1, 2]:
  data_index = 0
  batch, labels = generate_batch(batch_size=4, bag_window=bag_window)
  print('\nwith bag_window = %d:' % (bag_window))  
  print('    batch:', [[reverse_dictionary[w] for w in bi] for bi in batch])  
  print('    labels:', [reverse_dictionary[li] for li in labels.reshape(4)])
# Out:
# data: ['anarchism', 'originated', 'as', 'a', 'term', 'of', 'abuse', 'first', 'used', 'against', 'early', 'working', 'class', 'radicals', 'including', 'the']
#
# with bag_window = 1:
#     batch: [['anarchism', 'as'], ['originated', 'a'], ['as', 'term'], ['a', 'of']]
#     labels: ['originated', 'as', 'a', 'term']
#
# with bag_window = 2:
#     batch: [['anarchism', 'originated', 'a', 'term'], ['originated', 'as', 'term', 'of'], ['as', 'a', 'of', 'abuse'], ['a', 'term', 'abuse', 'first']]
#     labels: ['as', 'a', 'term', 'of']

# %%
batch_size = 128
embedding_size = 128 # Dimension of the embedding vector.
skip_window = 1 # How many words to consider left and right.
num_skips = 2 # How many times to reuse an input to generate a label.
valid_size = 16 # Random set of words to evaluate similarity on.
valid_window = 100 # Only pick dev samples in the head of the distribution.
# pick 16 samples from 100
valid_examples = np.array(random.sample(range(valid_window), valid_size//2))
valid_examples = np.append(valid_examples,random.sample(range(1000,1000+valid_window), valid_size//2))
num_sampled = 64 # Number of negative examples to sample.

graph = tf.Graph()

with graph.as_default(), tf.device('/cpu:0'):

    # Input data.
    train_dataset = tf.placeholder(tf.int32, shape=[batch_size,2*skip_window])
    train_labels = tf.placeholder(tf.int32, shape=[batch_size, 1])
    valid_dataset = tf.constant(valid_examples, dtype=tf.int32)

    # Variables.
    # embedding, vector for each word in the vocabulary
    embeddings = tf.Variable(tf.random_uniform([vocabulary_size, embedding_size], -1.0, 1.0))
    softmax_weights = tf.Variable(tf.truncated_normal([vocabulary_size, embedding_size],
                     stddev=1.0 / math.sqrt(embedding_size)))
    softmax_biases = tf.Variable(tf.zeros([vocabulary_size]))
    
    # Model.
    embeds = None
    for i in range(2*skip_window):
        embedding_i = tf.nn.embedding_lookup(embeddings, train_dataset[:,i])
        print('embedding %d shape: %s'%(i,embedding_i.get_shape().as_list()))
        emb_x,emb_y = embedding_i.get_shape().as_list()
        if embeds is None:
            embeds = tf.reshape(embedding_i,[emb_x,emb_y,1])
        else:
            embeds = tf.concat(2,[embeds,tf.reshape(embedding_i,[emb_x,emb_y,1])])

    assert embeds.get_shape().as_list()[2]==2*skip_window
    print("Concat embedding size: %s"%embeds.get_shape().as_list())
    avg_embed =  tf.reduce_mean(embeds,2,keep_dims=False)
    print("Avg embedding size: %s"%avg_embed.get_shape().as_list())

    loss = tf.reduce_mean(tf.nn.sampled_softmax_loss(softmax_weights, softmax_biases, avg_embed,
                       train_labels, num_sampled, vocabulary_size))
    optimizer = tf.train.AdagradOptimizer(1.0).minimize(loss)

    # We use the cosine distance:
    norm = tf.sqrt(tf.reduce_sum(tf.square(embeddings), 1, keep_dims=True))
    normalized_embeddings = embeddings / norm
    valid_embeddings = tf.nn.embedding_lookup(normalized_embeddings, valid_dataset)
    similarity = tf.matmul(valid_embeddings, tf.transpose(normalized_embeddings))
# Out:
# embedding 0 shape: [128, 128]
# embedding 1 shape: [128, 128]
# Concat embedding size: [128, 128, 2]
# Avg embedding size: [128, 128]

# %%
with tf.Session(graph=graph) as session:
    tf.global_variables_initializer().run()
    print('Initialized')
    average_loss = 0
    for step in range(num_steps):
        batch_data, batch_labels = generate_batch(batch_size, skip_window)
        feed_dict = {train_dataset : batch_data, train_labels : batch_labels}
        _, l = session.run([optimizer, loss], feed_dict=feed_dict)
        average_loss += l
        if step % 2000 == 0:
            if step > 0:
                average_loss = average_loss / 2000
                # The average loss is an estimate of the loss over the last 2000 batches.
            print('Average loss at step %d: %f' % (step, average_loss))
            average_loss = 0
        # note that this is expensive (~20% slowdown if computed every 500 steps)
        if step % 10000 == 0:
            sim = similarity.eval()
            for i in range(valid_size):
                valid_word = reverse_dictionary[valid_examples[i]]
                top_k = 8 # number of nearest neighbors
                nearest = (-sim[i, :]).argsort()[1:top_k+1]
                log = 'Nearest to %s:' % valid_word
                for k in range(top_k):
                    close_word = reverse_dictionary[nearest[k]]
                    log = '%s %s,' % (log, close_word)
                print(log)
    final_embeddings = normalized_embeddings.eval()
# Out:
# Initialized
# Average loss at step 0: 7.013042
# Nearest to four: nocturnal, subtly, subcontinent, ceo, filkers, grenade, asymptotes, jure,
# Nearest to were: argentine, bilbo, noises, coward, landform, unnamed, substance, bankhead,
# Nearest to state: muses, experimenter, theropod, sampled, athanasius, accelerator, assistive, blisters,
# Nearest to can: grassy, visigoths, rennie, disrespect, singularities, ideal, travelogue, heflin,
# Nearest to about: courtiers, witt, lambert, hamza, informs, resin, shikai, rice,
# Nearest to so: oblast, nabokov, excesses, homebrew, brute, bosporus, yosemite, beliefs,
# Nearest to when: monte, entirety, pittsburg, beowulf, wd, roald, sent, och,
# Nearest to up: porphyry, kickstart, col, deplete, journalism, hairy, abbas, frieza,
# Nearest to quite: cooperating, miraculous, lenient, surgeon, advises, refusal, magnesians, christi,
# Nearest to egypt: benford, pederastic, inverted, bust, plaques, cartagena, nernst, individualized,
# Nearest to square: lakeside, supercharged, sacra, adapts, merlin, armour, penalties, conservative,
# Nearest to shown: diluted, suffered, furigana, exiting, mainframes, tackle, fortunes, tutoring,
# Nearest to nobel: subscribe, maintained, massive, dane, situated, maximus, directions, devotional,
# Nearest to frac: westchester, elin, coming, immigrant, optimal, anoint, unattractive, seizure,
# Nearest to bill: bondage, interoperability, senate, exothermic, retractable, commentators, morphogenesis, clockless,
# Nearest to mean: libby, fax, appended, measurable, fireside, venn, lap, exuberance,
# Average loss at step 2000: 4.031476
# Average loss at step 4000: 3.505435
# Average loss at step 6000: 3.340933
# Average loss at step 8000: 3.195181
# Average loss at step 10000: 3.147946
# Nearest to four: five, nine, eight, six, three, seven, zero, two,
# Nearest to were: are, was, had, have, is, noises, nsc, collier,
# Nearest to state: muses, blue, occultation, sending, sampled, betraying, expressway, assistive,
# Nearest to can: would, may, will, might, should, could, must, never,
# Nearest to about: charging, strips, buck, fredric, sas, hyperbola, exclusively, glagolitic,
# Nearest to so: we, excesses, nabokov, oblast, friendship, summits, underwriting, mismanagement,
# Nearest to when: wd, if, picks, during, monte, though, veer, activator,
# Nearest to up: col, him, porphyry, ringing, roots, palette, generalize, expansion,
# Nearest to quite: cooperating, refusal, miraculous, advises, hickory, posthumously, christi, unmodified,
# Nearest to egypt: benford, cartagena, inverted, bust, plaques, pederastic, individualized, paralipomena,
# Nearest to square: lakeside, sacra, supercharged, superset, guiana, armour, rigging, penalties,
# Nearest to shown: diluted, suffered, mainframes, rank, durians, levee, lazenby, tackle,
# Nearest to nobel: following, massive, maintained, dane, devotional, subscribe, directions, dialysis,
# Nearest to frac: westchester, immigrant, optimal, elin, unattractive, coming, anoint, seizure,
# Nearest to bill: bondage, interoperability, commentators, retractable, exothermic, clockless, megawati, hci,
# Nearest to mean: libby, appended, lap, copious, fax, exuberance, measurable, view,
# Average loss at step 12000: 3.167554
# Average loss at step 14000: 3.126159
# Average loss at step 16000: 3.152667
# Average loss at step 18000: 3.104968
# Average loss at step 20000: 2.996386
# Nearest to four: six, five, eight, seven, three, nine, two, zero,
# Nearest to were: are, was, have, had, include, is, gamow, been,
# Nearest to state: occultation, muses, blue, sending, sampled, national, petroleum, swabian,
# Nearest to can: may, would, will, might, should, could, must, cannot,
# Nearest to about: charging, glagolitic, exclusively, thinner, buck, fredric, separators, appendicitis,
# Nearest to so: excesses, friendship, summits, we, nabokov, succumbing, consider, bosporus,
# Nearest to when: if, wd, picks, until, during, before, though, activator,
# Nearest to up: him, them, col, porphyry, magic, journalism, ringing, homer,
# Nearest to quite: cooperating, refusal, miraculous, hickory, unmodified, posthumously, disavow, advises,
# Nearest to egypt: inverted, bust, benford, cartagena, pederastic, plaques, individualized, paralipomena,
# Nearest to square: armour, superset, rigging, sacra, lakeside, amsterdam, guiana, merlin,
# Nearest to shown: diluted, suffered, mainframes, rank, durians, lazenby, levee, exclusive,
# Nearest to nobel: following, massive, maintained, devotional, dane, recaptured, subscribe, dialysis,
# Nearest to frac: westchester, optimal, immigrant, unattractive, elin, hodder, smith, transmutation,
# Nearest to bill: interoperability, bondage, commentators, clockless, retractable, opold, labourers, megawati,
# Nearest to mean: libby, understand, lap, appended, view, classified, exuberance, blunder,
# Average loss at step 22000: 3.052503
# Average loss at step 24000: 3.025723
# Average loss at step 26000: 2.991186
# Average loss at step 28000: 3.016494
# Average loss at step 30000: 2.992944
# Nearest to four: five, six, eight, three, seven, nine, two, zero,
# Nearest to were: are, have, was, had, been, gamow, be, nsc,
# Nearest to state: occultation, muses, sampled, national, congress, kick, renegades, sending,
# Nearest to can: may, would, could, might, will, should, must, cannot,
# Nearest to about: charging, thinner, exclusively, separators, glagolitic, rightly, appendicitis, hanns,
# Nearest to so: excesses, nabokov, dwt, argue, summits, friendship, bosporus, succumbing,
# Nearest to when: if, picks, wd, after, before, during, though, where,
# Nearest to up: him, them, porphyry, col, out, magic, journalism, lackey,
# Nearest to quite: unmodified, placed, hickory, refusal, omission, disavow, bonds, collected,
# Nearest to egypt: inverted, bust, cartagena, benford, pederastic, plaques, paralipomena, individualized,
# Nearest to square: armour, amsterdam, rigging, superset, guiana, lakeside, starship, sacra,
# Nearest to shown: diluted, seen, suffered, mainframes, rank, eurystheus, lazenby, durians,
# Nearest to nobel: following, massive, maintained, devotional, dane, recaptured, subscribe, dialysis,
# Nearest to frac: westchester, optimal, unattractive, mhz, transmutation, immigrant, hodder, elin,
# Nearest to bill: hci, opold, interoperability, clockless, psychomotor, commentators, retractable, ans,
# Nearest to mean: understand, view, libby, play, blunder, copious, exuberance, lap,
# Average loss at step 32000: 2.840596
# Average loss at step 34000: 2.944201
# Average loss at step 36000: 2.937829
# Average loss at step 38000: 2.940441
# Average loss at step 40000: 2.921988
# Nearest to four: five, six, three, seven, eight, nine, two, zero,
# Nearest to were: are, have, was, had, been, be, gamow, those,
# Nearest to state: occultation, casts, muses, government, national, congress, gerrymander, relational,
# Nearest to can: may, would, will, could, might, should, must, cannot,
# Nearest to about: charging, thinner, rightly, exclusively, separators, croatians, sas, appendicitis,
# Nearest to so: excesses, argue, dwt, nabokov, sclc, summits, consider, succumbing,
# Nearest to when: if, before, after, during, where, wd, though, activator,
# Nearest to up: him, out, them, off, porphyry, col, down, journalism,
# Nearest to quite: somewhat, bonds, placed, cunningham, completely, unmodified, elevator, disavow,
# Nearest to egypt: inverted, bust, pederastic, cartagena, benford, paralipomena, plaques, individualized,
# Nearest to square: armour, amsterdam, superset, rigging, giraffes, guiana, sacra, starship,
# Nearest to shown: seen, diluted, suffered, mainframes, resulted, eurystheus, durians, evolved,
# Nearest to nobel: following, massive, maintained, dane, devotional, recaptured, dialysis, directions,
# Nearest to frac: westchester, optimal, mhz, unattractive, hodder, transmutation, lister, smith,
# Nearest to bill: hci, series, interoperability, clockless, opold, retractable, psychomotor, evans,
# Nearest to mean: understand, blunder, copious, exuberance, view, libby, play, lap,
# Average loss at step 42000: 2.941147
# Average loss at step 44000: 2.946395
# Average loss at step 46000: 2.908641
# Average loss at step 48000: 2.868292
# Average loss at step 50000: 2.840398
# Nearest to four: five, six, seven, eight, three, nine, two, zero,
# Nearest to were: are, have, had, was, been, be, include, collier,
# Nearest to state: occultation, muses, congress, national, states, casts, government, gerrymander,
# Nearest to can: may, could, would, will, might, must, should, cannot,
# Nearest to about: charging, thinner, exclusively, that, separators, croatians, rightly, appendicitis,
# Nearest to so: excesses, dwt, sclc, argue, suggest, demo, yearly, heard,
# Nearest to when: if, before, after, where, during, while, although, until,
# Nearest to up: out, him, off, them, porphyry, down, col, lackey,
# Nearest to quite: very, somewhat, completely, extremely, bonds, not, less, cunningham,
# Nearest to egypt: bust, inverted, cartagena, pederastic, paralipomena, plaques, benford, begged,
# Nearest to square: superset, amsterdam, armour, giraffes, rigging, starship, guiana, eases,
# Nearest to shown: seen, diluted, suffered, resulted, mainframes, evolved, succeeded, argued,
# Nearest to nobel: dane, massive, dialysis, following, bodyline, devotional, recaptured, maximus,
# Nearest to frac: westchester, mhz, optimal, lister, transmutation, malacca, blurring, unattractive,
# Nearest to bill: hci, opold, series, interoperability, retractable, evans, clockless, psychomotor,
# Nearest to mean: understand, copious, blunder, exuberance, play, contain, view, libby,
# Average loss at step 52000: 2.890914
# Average loss at step 54000: 2.860330
# Average loss at step 56000: 2.861049
# Average loss at step 58000: 2.763299
# Average loss at step 60000: 2.829119
# Nearest to four: six, five, seven, eight, three, nine, two, zero,
# Nearest to were: are, have, had, was, been, be, include, gamow,
# Nearest to state: occultation, states, muses, casts, relational, congress, fsm, government,
# Nearest to can: may, could, will, would, might, should, must, cannot,
# Nearest to about: thinner, charging, rightly, that, separators, exclusively, resolutions, appendicitis,
# Nearest to so: excesses, dwt, argue, yearly, sclc, heard, suggest, interpret,
# Nearest to when: if, where, during, before, after, although, while, though,
# Nearest to up: out, him, off, down, them, porphyry, lackey, col,
# Nearest to quite: very, somewhat, extremely, completely, less, considered, bonds, not,
# Nearest to egypt: cartagena, inverted, bust, sheds, pederastic, paralipomena, fisheries, disagreement,
# Nearest to square: superset, starship, giraffes, armour, minority, rigging, amsterdam, hurry,
# Nearest to shown: seen, resulted, found, diluted, evolved, expressed, suffered, mainframes,
# Nearest to nobel: dane, dialysis, bodyline, maximus, devotional, subscribe, recaptured, massive,
# Nearest to frac: mhz, r, omega, westchester, x, blurring, t, malacca,
# Nearest to bill: opold, hci, retractable, evans, ans, john, interoperability, captain,
# Nearest to mean: understand, blunder, exuberance, contain, refer, copious, play, hold,
# Average loss at step 62000: 2.835130
# Average loss at step 64000: 2.780216
# Average loss at step 66000: 2.770934
# Average loss at step 68000: 2.717581
# Average loss at step 70000: 2.775888
# Nearest to four: three, five, six, seven, eight, nine, two, zero,
# Nearest to were: are, was, have, had, been, include, be, gamow,
# Nearest to state: states, occultation, government, casts, congress, muses, fsm, sending,
# Nearest to can: could, may, will, would, must, might, should, cannot,
# Nearest to about: thinner, charging, separators, exclusively, appendicitis, concerning, rightly, resolutions,
# Nearest to so: dwt, excesses, heard, yearly, sclc, argue, collectively, friendship,
# Nearest to when: if, before, after, where, during, while, though, although,
# Nearest to up: out, off, him, down, them, porphyry, lackey, peanuts,
# Nearest to quite: very, somewhat, extremely, completely, less, particularly, increasingly, considered,
# Nearest to egypt: cartagena, bust, inverted, fisheries, sheds, pederastic, paralipomena, billions,
# Nearest to square: superset, starship, amsterdam, armour, giraffes, minority, whitney, eases,
# Nearest to shown: seen, resulted, evolved, found, diluted, expressed, suffered, mentioned,
# Nearest to nobel: bodyline, dane, maximus, dialysis, moulds, devotional, subscribe, recaptured,
# Nearest to frac: x, mhz, omega, blurring, westchester, mathbf, optimal, r,
# Nearest to bill: opold, hci, interoperability, ans, retractable, evans, captain, longue,
# Nearest to mean: understand, exuberance, contain, blunder, refer, means, give, technicolor,
# Average loss at step 72000: 2.798927
# Average loss at step 74000: 2.656985
# Average loss at step 76000: 2.799472
# Average loss at step 78000: 2.819510
# Average loss at step 80000: 2.782194
# Nearest to four: six, five, three, seven, eight, nine, two, zero,
# Nearest to were: are, have, had, was, been, include, gamow, those,
# Nearest to state: states, occultation, government, casts, congress, muses, national, branch,
# Nearest to can: could, may, will, would, might, must, should, cannot,
# Nearest to about: concerning, thinner, charging, that, rightly, resolutions, exclusively, separators,
# Nearest to so: excesses, dwt, yearly, sclc, heard, too, collectively, rothbard,
# Nearest to when: if, during, after, before, where, although, though, while,
# Nearest to up: off, out, down, him, them, lackey, porphyry, back,
# Nearest to quite: very, somewhat, extremely, less, completely, increasingly, relatively, highly,
# Nearest to egypt: bust, cartagena, inverted, fisheries, pederastic, paralipomena, billions, sheds,
# Nearest to square: superset, starship, armour, whitney, giraffes, amsterdam, minority, eases,
# Nearest to shown: seen, resulted, found, evolved, mentioned, expressed, interpreted, described,
# Nearest to nobel: dane, dialysis, bodyline, devotional, moulds, maximus, naci, gulliver,
# Nearest to frac: x, mhz, omega, mathbf, westchester, blurring, optimal, malacca,
# Nearest to bill: opold, captain, ans, hci, john, interoperability, monrovia, longue,
# Nearest to mean: understand, exuberance, chance, technicolor, means, libby, view, translate,
# Average loss at step 82000: 2.677905
# Average loss at step 84000: 2.774566
# Average loss at step 86000: 2.740256
# Average loss at step 88000: 2.752762
# Average loss at step 90000: 2.742023
# Nearest to four: six, five, eight, seven, three, nine, two, zero,
# Nearest to were: are, have, had, those, include, was, been, gamow,
# Nearest to state: states, occultation, gerrymander, government, national, casts, muses, branch,
# Nearest to can: could, may, will, should, might, would, must, cannot,
# Nearest to about: concerning, thinner, rightly, resolutions, separators, exclusively, charging, appendicitis,
# Nearest to so: dwt, yearly, excesses, ignacy, rothbard, sclc, collectively, indoctrination,
# Nearest to when: if, before, after, where, while, although, during, though,
# Nearest to up: off, out, down, him, them, back, together, lackey,
# Nearest to quite: very, somewhat, extremely, less, completely, relatively, more, highly,
# Nearest to egypt: cartagena, bust, india, inverted, fisheries, asia, billions, differentials,
# Nearest to square: superset, whitney, starship, minority, giraffes, armour, onion, amsterdam,
# Nearest to shown: seen, mentioned, found, resulted, expressed, given, evolved, measured,
# Nearest to nobel: dane, dialysis, moulds, devotional, maximus, bodyline, naci, gulliver,
# Nearest to frac: omega, x, mhz, mathbf, blurring, optimal, westchester, int,
# Nearest to bill: megawati, senate, fasces, opold, interoperability, samarium, retractable, paco,
# Nearest to mean: understand, exuberance, chance, contain, means, play, change, technicolor,
# Average loss at step 92000: 2.688078
# Average loss at step 94000: 2.729035
# Average loss at step 96000: 2.706607
# Average loss at step 98000: 2.379633
# Average loss at step 100000: 2.422076
# Nearest to four: five, seven, six, eight, nine, three, zero, two,
# Nearest to were: are, have, was, had, include, been, be, those,
# Nearest to state: states, occultation, gerrymander, government, national, branch, congress, permanent,
# Nearest to can: could, will, may, might, would, should, must, cannot,
# Nearest to about: concerning, thinner, resolutions, rightly, appendicitis, charging, separators, contrary,
# Nearest to so: dwt, thus, yearly, collectively, too, sometimes, vla, excesses,
# Nearest to when: if, after, before, where, during, while, though, although,
# Nearest to up: off, out, down, him, them, back, together, lackey,
# Nearest to quite: very, somewhat, extremely, less, relatively, completely, highly, more,
# Nearest to egypt: bust, india, cartagena, fisheries, asia, inverted, china, billions,
# Nearest to square: superset, whitney, starship, giraffes, adonijah, onion, plethora, amsterdam,
# Nearest to shown: seen, found, mentioned, resulted, given, expressed, measured, evolved,
# Nearest to nobel: dane, bodyline, moulds, maximus, unmatched, naci, devotional, dialysis,
# Nearest to frac: omega, mhz, mathbf, blurring, optimal, n, westchester, hogmanay,
# Nearest to bill: senate, megawati, hci, opold, interoperability, series, paco, captain,
# Nearest to mean: understand, exuberance, chance, contain, pass, display, play, technicolor,

# %%
num_points = 400

tsne = TSNE(perplexity=30, n_components=2, init='pca', n_iter=5000)
two_d_embeddings = tsne.fit_transform(final_embeddings[1:num_points+1, :])

# %%
def plot(embeddings, labels):
    assert embeddings.shape[0] >= len(labels), 'More labels than embeddings'
    pylab.figure(figsize=(15,15))  # in inches
    for i, label in enumerate(labels):
        x, y = embeddings[i,:]
        pylab.scatter(x, y)
        pylab.annotate(label, xy=(x, y), xytext=(5, 2), textcoords='offset points',
                   ha='right', va='bottom')
    pylab.show()

words = [reverse_dictionary[i] for i in range(1, num_points+1)]
plot(two_d_embeddings, words)
